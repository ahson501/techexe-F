# %%
import tensorflow as tf

# %%
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
import numpy as np

# %%
pip install gputil
# Out:
# Collecting gputil
#   Downloading GPUtil-1.4.0.tar.gz (5.5 kB)
# Building wheels for collected packages: gputil
#   Building wheel for gputil (setup.py) ... done
#   Created wheel for gputil: filename=GPUtil-1.4.0-py3-none-any.whl size=8218 sha256=929a7413677f19d5b4e188e41ab041a3ee06582e3310bd7c4abeb232b8c80aff
#   Stored in directory: /root/.cache/pip/wheels/79/c1/b2/b6fc2647f693a084da25e1d31328ab3dbb565cc58fea37e973
# Successfully built gputil
# Installing collected packages: gputil
# Successfully installed gputil-1.4.0
# WARNING: You are using pip version 20.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import scipy.stats as st

# %%
import tensorflow as tf
with tf.device('/GPU:0'):
  a = tf.constant([[1.0, 2.0], [4.0, 5.0]])

# %%
pip install scipy
# Out:
# Collecting scipy
#   Downloading scipy-1.5.4-cp36-cp36m-manylinux1_x86_64.whl (25.9 MB)
#      |████████████████████████████████| 25.9 MB 3.2 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.6/dist-packages (from scipy) (1.18.5)
# Installing collected packages: scipy
# Successfully installed scipy-1.5.4
# WARNING: You are using pip version 20.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import sklearn.linear_model as lm

# %%
pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-0.24.2-cp36-cp36m-manylinux2010_x86_64.whl (22.2 MB)
#      |████████████████████████████████| 22.2 MB 410 kB/s eta 0:00:01
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.6/dist-packages (from scikit-learn) (1.5.4)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from scikit-learn) (1.18.5)
# Collecting joblib>=0.11
#   Downloading joblib-1.1.1-py2.py3-none-any.whl (309 kB)
#      |████████████████████████████████| 309 kB 29.5 MB/s eta 0:00:01
# Installing collected packages: threadpoolctl, joblib, scikit-learn
# Successfully installed joblib-1.1.1 scikit-learn-0.24.2 threadpoolctl-3.1.0
# WARNING: You are using pip version 20.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
def f(x):
    return np.exp(3 * x)

# %%
from numpy import *
x_tr = random.randint(low=10, high=30, size=6)

# %%
gpus = tf.config.list_physical_devices("GPU")

# %%
import GPUtil
GPUtil.getAvailable()
# Out:
# [0]

# %%
pip install torch
# Out:
# Collecting torch
#   Downloading torch-1.10.2-cp36-cp36m-manylinux1_x86_64.whl (881.9 MB)
#      |████████████████████████████████| 881.9 MB 26 kB/s  eta 0:00:0124     |███████████████████▋            | 539.5 MB 8.6 MB/s eta 0:00:40     |███████████████████████         | 631.2 MB 65.1 MB/s eta 0:00:04     |█████████████████████████       | 690.6 MB 44.0 MB/s eta 0:00:05     |██████████████████████████████▎ | 833.0 MB 719 kB/s eta 0:01:09
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.6/dist-packages (from torch) (3.7.4.3)
# Collecting dataclasses; python_version < "3.7"
#   Downloading dataclasses-0.8-py3-none-any.whl (19 kB)
# Installing collected packages: dataclasses, torch
# Successfully installed dataclasses-0.8 torch-1.10.2
# WARNING: You are using pip version 20.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
# test_gpu.py
import tensorflow as tf
from tensorflow.python.client import device_lib

print("Available devices:")
print(device_lib.list_local_devices())

if tf.config.experimental.list_physical_devices('GPU'):
    print("GPU is available and recognized.")
else:
    print("GPU is not available.")
# Out:
# Available devices:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 18359839462186154932
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 2927522268061949462
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 15522837729123146038
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 15579919168
# locality {
#   bus_id: 2
#   numa_node: 1
#   links {
#   }
# }
# incarnation: 6557947903417457958
# physical_device_desc: "device: 0, name: Quadro RTX 5000, pci bus id: 0000:86:00.0, compute capability: 7.5"
# ]
# GPU is available and recognized.
